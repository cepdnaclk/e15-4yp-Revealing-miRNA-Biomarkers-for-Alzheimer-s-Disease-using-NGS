# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import scipy.stats as stats
from scipy.stats import poisson

# %%
import pandas as pd

#Read the datafile of selected features from statistical analysis
df = pd.read_excel(r'df_new.xls',index_col=0)

# %%
df
# Out:
#        hsa-mir-30a:hsa-miR-30a-3p  hsa-mir-550a-1:hsa-miR-550a-3p  \
# AD.1                   132.885714                      958.457143
# AD.2                   282.371429                      794.542857
# AD.3                   179.371429                      541.785714
# AD.4                   115.700000                     1011.342857
# AD.5                    89.857143                      429.757143
# ...                           ...                             ...
# AD.43                  106.742857                      339.700000
# AD.44                  117.857143                      207.271429
# AD.45                  175.642857                      481.685714
# AD.46                  157.785714                      349.342857
# AD.47                  214.900000                      304.814286
#
#        hsa-mir-29a:hsa-miR-29a-3p  hsa-mir-628:hsa-miR-628-3p  \
# AD.1                    78.957143                    0.000000
# AD.2                    64.457143                    1.542857
# AD.3                    69.814286                    2.800000
# AD.4                    65.542857                    0.942857
# AD.5                    32.228571                    0.000000
# ...                           ...                         ...
# AD.43                   48.514286                    2.728571
# AD.44                   66.700000                    3.028571
# AD.45                   59.871429                    3.285714
# AD.46                   26.000000                   16.514286
# AD.47                    0.000000                   24.885714
#
#        hsa-mir-26a-2:hsa-miR-26a-5p  hsa-mir-106b:hsa-miR-106b-5p  \
# AD.1                    3546.471429                    117.857143
# AD.2                   14464.157143                     40.428571
# AD.3                    8648.271429                     18.542857
# AD.4                    7038.985714                     72.342857
# AD.5                    4315.285714                     84.800000
# ...                             ...                           ...
# AD.43                   8317.371429                     65.542857
# AD.44                   5995.142857                    202.771429
# AD.45                   8317.371429                     47.671429
# AD.46                   8317.371429                     33.728571
# AD.47                   3285.814286                     75.857143
#
#        hsa-mir-4781:hsa-miR-4781-3p  hsa-mir-10b:hsa-miR-10b-5p  \
# AD.1                      21.828571                  902.114286
# AD.2                      35.728571                 1840.628571
# AD.3                      23.057143                 1459.242857
# AD.4                      31.471429                  289.042857
# AD.5                      27.728571                  148.500000
# ...                             ...                         ...
# AD.43                     25.671429                 1621.442857
# AD.44                     24.185714                  771.614286
# AD.45                     37.728571                 1291.942857
# AD.46                     37.728571                  275.814286
# AD.47                      0.000000                  168.942857
#
#        hsa-mir-215:hsa-miR-215  hsa-mir-548aj-2:hsa-miR-548g-5p  ...  \
# AD.1               6335.742857                         1.100000  ...
# AD.2               3969.000000                         5.157143  ...
# AD.3               2045.757143                         2.800000  ...
# AD.4               2860.557143                         4.714286  ...
# AD.5               1621.442857                         1.357143  ...
# ...                        ...                              ...  ...
# AD.43              3969.000000                         9.257143  ...
# AD.44              5080.557143                         7.614286  ...
# AD.45              3969.000000                         3.285714  ...
# AD.46              1548.071429                         0.000000  ...
# AD.47              5080.557143                         0.000000  ...
#
#        brain-mir-431:brain-mir-431  brain-mir-23:brain-mir-23  \
# AD.1                      7.285714                  21.828571
# AD.2                     13.142857                  23.942857
# AD.3                      2.800000                  19.085714
# AD.4                      9.514286                  28.257143
# AD.5                     15.428571                   9.514286
# ...                            ...                        ...
# AD.43                     1.585714                   9.257143
# AD.44                     6.685714                  13.700000
# AD.45                    11.885714                  20.085714
# AD.46                     0.000000                   5.942857
# AD.47                    24.885714                   0.000000
#
#        brain-mir-427:brain-mir-427  brain-mir-392:brain-mir-392  \
# AD.1                     12.471429                    13.142857
# AD.2                     18.285714                    16.985714
# AD.3                     29.200000                    11.400000
# AD.4                      3.714286                     9.514286
# AD.5                     37.728571                    27.728571
# ...                            ...                          ...
# AD.43                     5.114286                     1.585714
# AD.44                     5.042857                     0.000000
# AD.45                    24.185714                    16.514286
# AD.46                     7.885714                    54.371429
# AD.47                    24.885714                    75.857143
#
#        brain-mir-192:brain-mir-192  brain-mir-53:brain-mir-53  \
# AD.1                      6.385714                   2.571429
# AD.2                     10.485714                   7.414286
# AD.3                      5.600000                  11.400000
# AD.4                      7.185714                  13.442857
# AD.5                     10.600000                  15.428571
# ...                            ...                        ...
# AD.43                     2.728571                  19.614286
# AD.44                     1.014286                   6.242857
# AD.45                    13.014286                  14.871429
# AD.46                    10.071429                   7.885714
# AD.47                     0.000000                   0.000000
#
#        brain-mir-112:brain-mir-112  brain-mir-159:brain-mir-159  \
# AD.1                     13.571429                   310.414286
# AD.2                     18.285714                   297.985714
# AD.3                     14.871429                   275.814286
# AD.4                     19.800000                   275.814286
# AD.5                     10.600000                   187.242857
# ...                            ...                          ...
# AD.43                    13.342857                   157.785714
# AD.44                     4.471429                   100.871429
# AD.45                    19.085714                   250.485714
# AD.46                    21.828571                   297.985714
# AD.47                    24.885714                   584.742857
#
#        brain-mir-328:brain-mir-328  class
# AD.1                      7.285714      1
# AD.2                     16.371429      1
# AD.3                     16.185714      1
# AD.4                     14.757143      1
# AD.5                      6.457143      1
# ...                            ...    ...
# AD.43                    18.914286      1
# AD.44                     9.642857      1
# AD.45                    11.400000      1
# AD.46                    16.514286      1
# AD.47                    24.885714      1
#
# [69 rows x 220 columns]

# %% [markdown]
# ### Univariate Selection

# %%
#Select the columns of features
X=df.loc[: , df.columns != 'class']
X
# Out:
#        hsa-mir-30a:hsa-miR-30a-3p  hsa-mir-550a-1:hsa-miR-550a-3p  \
# AD.1                   132.885714                      958.457143
# AD.2                   282.371429                      794.542857
# AD.3                   179.371429                      541.785714
# AD.4                   115.700000                     1011.342857
# AD.5                    89.857143                      429.757143
# ...                           ...                             ...
# AD.43                  106.742857                      339.700000
# AD.44                  117.857143                      207.271429
# AD.45                  175.642857                      481.685714
# AD.46                  157.785714                      349.342857
# AD.47                  214.900000                      304.814286
#
#        hsa-mir-29a:hsa-miR-29a-3p  hsa-mir-628:hsa-miR-628-3p  \
# AD.1                    78.957143                    0.000000
# AD.2                    64.457143                    1.542857
# AD.3                    69.814286                    2.800000
# AD.4                    65.542857                    0.942857
# AD.5                    32.228571                    0.000000
# ...                           ...                         ...
# AD.43                   48.514286                    2.728571
# AD.44                   66.700000                    3.028571
# AD.45                   59.871429                    3.285714
# AD.46                   26.000000                   16.514286
# AD.47                    0.000000                   24.885714
#
#        hsa-mir-26a-2:hsa-miR-26a-5p  hsa-mir-106b:hsa-miR-106b-5p  \
# AD.1                    3546.471429                    117.857143
# AD.2                   14464.157143                     40.428571
# AD.3                    8648.271429                     18.542857
# AD.4                    7038.985714                     72.342857
# AD.5                    4315.285714                     84.800000
# ...                             ...                           ...
# AD.43                   8317.371429                     65.542857
# AD.44                   5995.142857                    202.771429
# AD.45                   8317.371429                     47.671429
# AD.46                   8317.371429                     33.728571
# AD.47                   3285.814286                     75.857143
#
#        hsa-mir-4781:hsa-miR-4781-3p  hsa-mir-10b:hsa-miR-10b-5p  \
# AD.1                      21.828571                  902.114286
# AD.2                      35.728571                 1840.628571
# AD.3                      23.057143                 1459.242857
# AD.4                      31.471429                  289.042857
# AD.5                      27.728571                  148.500000
# ...                             ...                         ...
# AD.43                     25.671429                 1621.442857
# AD.44                     24.185714                  771.614286
# AD.45                     37.728571                 1291.942857
# AD.46                     37.728571                  275.814286
# AD.47                      0.000000                  168.942857
#
#        hsa-mir-215:hsa-miR-215  hsa-mir-548aj-2:hsa-miR-548g-5p  ...  \
# AD.1               6335.742857                         1.100000  ...
# AD.2               3969.000000                         5.157143  ...
# AD.3               2045.757143                         2.800000  ...
# AD.4               2860.557143                         4.714286  ...
# AD.5               1621.442857                         1.357143  ...
# ...                        ...                              ...  ...
# AD.43              3969.000000                         9.257143  ...
# AD.44              5080.557143                         7.614286  ...
# AD.45              3969.000000                         3.285714  ...
# AD.46              1548.071429                         0.000000  ...
# AD.47              5080.557143                         0.000000  ...
#
#        brain-mir-413:brain-mir-413  brain-mir-431:brain-mir-431  \
# AD.1                      6.385714                     7.285714
# AD.2                      2.671429                    13.142857
# AD.3                      6.942857                     2.800000
# AD.4                      4.714286                     9.514286
# AD.5                      1.357143                    15.428571
# ...                            ...                          ...
# AD.43                     0.000000                     1.585714
# AD.44                     1.785714                     6.685714
# AD.45                     2.442857                    11.885714
# AD.46                    10.071429                     0.000000
# AD.47                     0.000000                    24.885714
#
#        brain-mir-23:brain-mir-23  brain-mir-427:brain-mir-427  \
# AD.1                   21.828571                    12.471429
# AD.2                   23.942857                    18.285714
# AD.3                   19.085714                    29.200000
# AD.4                   28.257143                     3.714286
# AD.5                    9.514286                    37.728571
# ...                          ...                          ...
# AD.43                   9.257143                     5.114286
# AD.44                  13.700000                     5.042857
# AD.45                  20.085714                    24.185714
# AD.46                   5.942857                     7.885714
# AD.47                   0.000000                    24.885714
#
#        brain-mir-392:brain-mir-392  brain-mir-192:brain-mir-192  \
# AD.1                     13.142857                     6.385714
# AD.2                     16.985714                    10.485714
# AD.3                     11.400000                     5.600000
# AD.4                      9.514286                     7.185714
# AD.5                     27.728571                    10.600000
# ...                            ...                          ...
# AD.43                     1.585714                     2.728571
# AD.44                     0.000000                     1.014286
# AD.45                    16.514286                    13.014286
# AD.46                    54.371429                    10.071429
# AD.47                    75.857143                     0.000000
#
#        brain-mir-53:brain-mir-53  brain-mir-112:brain-mir-112  \
# AD.1                    2.571429                    13.571429
# AD.2                    7.414286                    18.285714
# AD.3                   11.400000                    14.871429
# AD.4                   13.442857                    19.800000
# AD.5                   15.428571                    10.600000
# ...                          ...                          ...
# AD.43                  19.614286                    13.342857
# AD.44                   6.242857                     4.471429
# AD.45                  14.871429                    19.085714
# AD.46                   7.885714                    21.828571
# AD.47                   0.000000                    24.885714
#
#        brain-mir-159:brain-mir-159  brain-mir-328:brain-mir-328
# AD.1                    310.414286                     7.285714
# AD.2                    297.985714                    16.371429
# AD.3                    275.814286                    16.185714
# AD.4                    275.814286                    14.757143
# AD.5                    187.242857                     6.457143
# ...                            ...                          ...
# AD.43                   157.785714                    18.914286
# AD.44                   100.871429                     9.642857
# AD.45                   250.485714                    11.400000
# AD.46                   297.985714                    16.514286
# AD.47                   584.742857                    24.885714
#
# [69 rows x 219 columns]

# %%
#Select the class column
Y=df.loc[: , df.columns == 'class']
Y
# Out:
#        class
# AD.1       1
# AD.2       1
# AD.3       1
# AD.4       1
# AD.5       1
# ...      ...
# AD.43      1
# AD.44      1
# AD.45      1
# AD.46      1
# AD.47      1
#
# [69 rows x 1 columns]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Feature','Score'] 
selectedFeatures = featureScores.nlargest(219,'Score')

df_219F = df[selectedFeatures['Feature'].values]
df_219F['class'] = Y
df_219F.head()
# Out:
#       hsa-mir-92b:hsa-miR-92b-3p  hsa-mir-484:hsa-miR-484  \
# AD.1                44281.771429             28534.842857
# AD.2                75224.671429             38774.300000
# AD.3                75224.671429             28534.842857
# AD.4                75224.671429             33664.228571
# AD.5                75224.671429             28534.842857
#
#       hsa-mir-30d:hsa-miR-30d-5p  hsa-let-7a-2:hsa-let-7a-5p  \
# AD.1                18412.171429                14464.157143
# AD.2                19986.471429                12957.585714
# AD.3                22008.228571                19986.471429
# AD.4                19986.471429                14464.157143
# AD.5                 9603.485714                18412.171429
#
#       hsa-let-7a-1:hsa-let-7a-5p  hsa-let-7a-3:hsa-let-7a-5p  \
# AD.1                13483.985714                12957.585714
# AD.2                12292.485714                11795.185714
# AD.3                18412.171429                17337.628571
# AD.4                13483.985714                12957.585714
# AD.5                17337.628571                16431.185714
#
#       hsa-mir-30a:hsa-miR-30a-5p  hsa-let-7f-2:hsa-let-7f-5p  \
# AD.1                19986.471429                12292.485714
# AD.2                18412.171429                11305.157143
# AD.3                14464.157143                16431.185714
# AD.4                16431.185714                12292.485714
# AD.5                10289.771429                15264.714286
#
#       hsa-mir-148a:hsa-miR-148a-3p  hsa-mir-425:hsa-miR-425-5p  ...  \
# AD.1                    689.014286                 8317.371429  ...
# AD.2                    467.342857                 5287.057143  ...
# AD.3                    328.071429                 7038.985714  ...
# AD.4                    376.457143                 4888.300000  ...
# AD.5                    357.028571                 3755.471429  ...
#
#       hsa-let-7f-1:hsa-let-7f-1-3p  hsa-mir-3614:hsa-miR-3614-5p  \
# AD.1                     11.142857                      4.914286
# AD.2                      9.128571                      2.671429
# AD.3                     13.014286                      8.157143
# AD.4                     13.442857                      2.671429
# AD.5                      1.357143                      5.114286
#
#       hsa-mir-659:hsa-miR-659-5p  hsa-mir-874:hsa-miR-874  \
# AD.1                   10.257143                15.585714
# AD.2                    5.157143                 5.157143
# AD.3                   16.185714                 1.357143
# AD.4                   12.157143                10.171429
# AD.5                    5.114286                 9.514286
#
#       brain-mir-328:brain-mir-328  hsa-mir-199a-1:hsa-miR-199a-5p  \
# AD.1                     7.285714                       35.728571
# AD.2                    16.371429                       17.871429
# AD.3                    16.185714                       41.828571
# AD.4                    14.757143                       26.000000
# AD.5                     6.457143                        1.357143
#
#       hsa-mir-199a-2:hsa-miR-199a-5p  hsa-mir-191:hsa-miR-191-3p  \
# AD.1                       35.728571                   12.471429
# AD.2                       17.871429                   10.485714
# AD.3                       41.828571                   22.071429
# AD.4                       26.000000                   13.442857
# AD.5                        1.357143                   12.471429
#
#       hsa-mir-4792:hsa-miR-4792  class
# AD.1                   2.571429      1
# AD.2                   0.000000      1
# AD.3                   1.357143      1
# AD.4                   0.942857      1
# AD.5                   0.000000      1
#
# [5 rows x 220 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(  selectedFeatures["Feature"], selectedFeatures["Score"], label='linear')

plt.xlabel('Feature')
plt.ylabel('Score')
plt.title('Univariate Selection')
plt.show()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
         
model = RandomForestClassifier(n_estimators=10000,  n_jobs=-1)
model.fit(X,Y)

#Select the best 50 features depend on feature importances
feat_imp = pd.Series(model.feature_importances_, index=X.columns)
rf_sel = feat_imp.nlargest(50)
rf_sel.to_excel("random_50.xls")
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
#Selected miRNAs
pl = rf_sel.plot(rot=90)
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
from sklearn import preprocessing

#Defining a function to normalize a dataframe
def dfNormalize(dataFrame):
    minMaxScaler = preprocessing.MinMaxScaler(feature_range=(1, 2))
    X_minMax = minMaxScaler.fit_transform(dataFrame)
    X_scaled = pd.DataFrame(X_minMax, columns = dataFrame.columns, index = dataFrame.index)
    return X_scaled

# %%
#Create the dataframe for selected miRNAs from random forest
df_RF = df[pd.DataFrame(rf_sel).T.columns]

#Normalize the datafram of random forest
df_RF_Norm = dfNormalize(df_RF)

#Round the normalized values upto 2 decimal points
df_RF_Norm = round(dfNormalize(df_RF),2)
df_RF_Norm.head()
# Out:
#       hsa-mir-144:hsa-miR-144-5p  hsa-mir-30d:hsa-miR-30d-5p  \
# AD.1                        1.11                        1.55
# AD.2                        1.05                        1.62
# AD.3                        1.04                        1.71
# AD.4                        1.07                        1.62
# AD.5                        1.21                        1.16
#
#       hsa-mir-4781:hsa-miR-4781-3p  brain-mir-112:brain-mir-112  \
# AD.1                          1.30                         1.25
# AD.2                          1.48                         1.35
# AD.3                          1.31                         1.28
# AD.4                          1.43                         1.38
# AD.5                          1.38                         1.19
#
#       hsa-let-7a-1:hsa-let-7a-5p  hsa-let-7f-1:hsa-let-7f-5p  \
# AD.1                        1.21                        1.30
# AD.2                        1.17                        1.22
# AD.3                        1.37                        1.48
# AD.4                        1.21                        1.30
# AD.5                        1.33                        1.44
#
#       hsa-let-7f-2:hsa-let-7f-5p  hsa-mir-3157:hsa-miR-3157-3p  \
# AD.1                        1.27                          1.36
# AD.2                        1.22                          1.42
# AD.3                        1.45                          1.41
# AD.4                        1.27                          1.53
# AD.5                        1.40                          1.04
#
#       hsa-mir-425:hsa-miR-425-5p  hsa-mir-148b:hsa-miR-148b-5p  ...  \
# AD.1                        1.39                          1.62  ...
# AD.2                        1.20                          1.63  ...
# AD.3                        1.31                          1.42  ...
# AD.4                        1.18                          1.69  ...
# AD.5                        1.11                          1.45  ...
#
#       brain-mir-219:brain-mir-219  hsa-mir-505:hsa-miR-505-3p  \
# AD.1                         1.40                        1.19
# AD.2                         2.00                        1.32
# AD.3                         1.78                        1.25
# AD.4                         1.81                        1.25
# AD.5                         1.24                        1.23
#
#       hsa-mir-589:hsa-miR-589-5p  hsa-mir-2110:hsa-miR-2110  \
# AD.1                        1.43                       1.10
# AD.2                        1.26                       1.21
# AD.3                        1.07                       1.23
# AD.4                        1.34                       1.35
# AD.5                        1.62                       1.32
#
#       hsa-mir-101-1:hsa-miR-101-3p  hsa-mir-30a:hsa-miR-30a-5p  \
# AD.1                          1.20                        1.73
# AD.2                          1.04                        1.65
# AD.3                          1.04                        1.45
# AD.4                          1.05                        1.55
# AD.5                          1.13                        1.24
#
#       hsa-mir-548h-5:hsa-miR-548h-5p  hsa-mir-144:hsa-miR-144-3p  \
# AD.1                            1.04                        1.04
# AD.2                            1.17                        1.01
# AD.3                            1.09                        1.01
# AD.4                            1.24                        1.02
# AD.5                            1.05                        1.06
#
#       hsa-mir-24-1:hsa-miR-24-3p  hsa-mir-3909:hsa-miR-3909
# AD.1                        1.24                       1.37
# AD.2                        1.40                       1.36
# AD.3                        1.31                       1.28
# AD.4                        1.21                       1.53
# AD.5                        1.22                       1.24
#
# [5 rows x 50 columns]

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

X = df.iloc[:,0:219].values
feature_names = df.columns[0:219].values

train_features = X

model = PCA(n_components=69).fit(train_features)
X_pc = model.transform(train_features)

#Number of components
n_pcs= model.components_.shape[0]

#Get the index of the most important feature on each component
most_important_index = [np.abs(model.components_[i]).argmax() for i in range(n_pcs)]

#Get the names of the most important features
most_important_names = [feature_names[most_important_index[i]] for i in range(n_pcs)]

#Create the dataframe for selected miRNAs from PCA
df_PCA = df[most_important_names]

df_PCA = df_PCA.T.drop_duplicates().T


df_PCA.head()
# Out:
#       hsa-mir-92b:hsa-miR-92b-3p  hsa-mir-25:hsa-miR-25-3p  \
# AD.1                44281.771429              33664.228571
# AD.2                75224.671429              44281.771429
# AD.3                75224.671429              44281.771429
# AD.4                75224.671429              44281.771429
# AD.5                75224.671429              55604.657143
#
#       hsa-mir-484:hsa-miR-484  hsa-mir-30d:hsa-miR-30d-5p  \
# AD.1             28534.842857                18412.171429
# AD.2             38774.300000                19986.471429
# AD.3             28534.842857                22008.228571
# AD.4             33664.228571                19986.471429
# AD.5             28534.842857                 9603.485714
#
#       hsa-let-7c:hsa-let-7c  hsa-mir-423:hsa-miR-423-3p  \
# AD.1            7977.442857                15264.714286
# AD.2            6335.742857                15264.714286
# AD.3           10289.771429                13483.985714
# AD.4            9137.385714                17337.628571
# AD.5           19986.471429                12292.485714
#
#       hsa-mir-363:hsa-miR-363-3p  hsa-mir-215:hsa-miR-215  \
# AD.1                 5995.142857              6335.742857
# AD.2                 7977.442857              3969.000000
# AD.3                 7467.342857              2045.757143
# AD.4                 8648.271429              2860.557143
# AD.5                 6335.742857              1621.442857
#
#       hsa-mir-3615:hsa-miR-3615  hsa-mir-186:hsa-miR-186-5p  ...  \
# AD.1                3755.471429                 9603.485714  ...
# AD.2                9137.385714                 4888.300000  ...
# AD.3                4888.300000                 3285.814286  ...
# AD.4                5080.557143                 5287.057143  ...
# AD.5                4888.300000                 3285.814286  ...
#
#       hsa-mir-1304:hsa-miR-1304-3p  hsa-mir-98:hsa-miR-98  \
# AD.1                    207.271429             113.742857
# AD.2                    179.371429             109.128571
# AD.3                    256.671429             175.642857
# AD.4                    239.971429             212.042857
# AD.5                    152.628571             161.114286
#
#       brain-mir-159:brain-mir-159  hsa-mir-93:hsa-miR-93-3p  \
# AD.1                   310.414286                262.100000
# AD.2                   297.985714                226.371429
# AD.3                   275.814286                333.728571
# AD.4                   275.814286                289.042857
# AD.5                   187.242857                195.014286
#
#       hsa-mir-3605:hsa-miR-3605-3p  hsa-mir-589:hsa-miR-589-5p  \
# AD.1                    398.157143                  529.414286
# AD.2                    541.785714                  388.457143
# AD.3                    672.414286                  230.585714
# AD.4                    638.942857                  454.614286
# AD.5                    398.157143                  689.014286
#
#       hsa-mir-126:hsa-miR-126-3p  hsa-mir-5010:hsa-miR-5010-3p  \
# AD.1                   47.671429                    207.271429
# AD.2                   50.442857                    250.485714
# AD.3                   91.342857                    282.371429
# AD.4                   66.700000                    236.157143
# AD.5                   70.928571                    187.242857
#
#       hsa-mir-1307:hsa-miR-1307-3p  hsa-mir-4781:hsa-miR-4781-3p
# AD.1                    145.442857                     21.828571
# AD.2                     64.457143                     35.728571
# AD.3                     86.685714                     23.057143
# AD.4                     46.071429                     31.471429
# AD.5                    304.814286                     27.728571
#
# [5 rows x 52 columns]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(df_PCA,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(df_PCA.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score'] 

selectedFeatures = featureScores.nlargest(50,'Score')
selectedFeatures.to_excel("pca_50.xls")
pca_array = featureScores[["Features"]].to_numpy()

pd.options.mode.chained_assignment = None

df_PCA = df[selectedFeatures['Features'].values]

#Round the normalized values upto 2 decimal points
df_PCA_Norm = round(dfNormalize(df_PCA),2)
df_PCA_Norm.head()
# Out:
#       hsa-mir-92b:hsa-miR-92b-3p  hsa-mir-484:hsa-miR-484  \
# AD.1                        1.39                     1.22
# AD.2                        1.72                     1.33
# AD.3                        1.72                     1.22
# AD.4                        1.72                     1.27
# AD.5                        1.72                     1.22
#
#       hsa-mir-30d:hsa-miR-30d-5p  hsa-let-7a-1:hsa-let-7a-5p  \
# AD.1                        1.55                        1.21
# AD.2                        1.62                        1.17
# AD.3                        1.71                        1.37
# AD.4                        1.62                        1.21
# AD.5                        1.16                        1.33
#
#       hsa-let-7f-2:hsa-let-7f-5p  hsa-mir-148a:hsa-miR-148a-3p  \
# AD.1                        1.27                          1.09
# AD.2                        1.22                          1.05
# AD.3                        1.45                          1.03
# AD.4                        1.27                          1.04
# AD.5                        1.40                          1.03
#
#       hsa-let-7f-1:hsa-let-7f-5p  hsa-mir-363:hsa-miR-363-3p  \
# AD.1                        1.30                        1.17
# AD.2                        1.22                        1.28
# AD.3                        1.48                        1.25
# AD.4                        1.30                        1.31
# AD.5                        1.44                        1.19
#
#       hsa-let-7g:hsa-let-7g-5p  hsa-mir-151a:hsa-miR-151a-3p  ...  \
# AD.1                      1.11                          1.10  ...
# AD.2                      1.09                          1.44  ...
# AD.3                      1.17                          1.33  ...
# AD.4                      1.15                          1.23  ...
# AD.5                      1.39                          1.08  ...
#
#       hsa-mir-3158-2:hsa-miR-3158-3p  hsa-mir-550a-2:hsa-miR-550a-3p  \
